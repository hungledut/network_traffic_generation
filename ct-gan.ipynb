# %%
import pandas as pd
data = pd.read_csv('/kaggle/input/unsw-dataset/UNSW_NB15_testing-set.csv')
data = data.drop(columns=['id'])
data
# Out:
#              dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0       0.121478   tcp       -   FIN      6      4     258     172
# 1       0.649902   tcp       -   FIN     14     38     734   42014
# 2       1.623129   tcp       -   FIN      8     16     364   13186
# 3       1.681642   tcp     ftp   FIN     12     12     628     770
# 4       0.449454   tcp       -   FIN     10      6     534     268
# ...          ...   ...     ...   ...    ...    ...     ...     ...
# 175336  0.000009   udp     dns   INT      2      0     114       0
# 175337  0.505762   tcp       -   FIN     10      8     620     354
# 175338  0.000009   udp     dns   INT      2      0     114       0
# 175339  0.000009   udp     dns   INT      2      0     114       0
# 175340  0.000009   udp     dns   INT      2      0     114       0
#
#                  rate  sttl  ...  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 0           74.087490   252  ...                 1               1
# ...

# %%
# !pip install category_encoders

# %%
dataset = data.sample(n=10000)
dataset
# Out:
#              dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 129193  0.000008   udp     dns   INT      2      0     114       0
# 47680   0.477710   tcp       -   FIN     10      6    1162     268
# 59235   0.000008  unas       -   INT      2      0     200       0
# 149883  0.000010   udp     dns   INT      2      0     114       0
# 152171  0.000009   udp     dns   INT      2      0     114       0
# ...          ...   ...     ...   ...    ...    ...     ...     ...
# 74285   2.392009   tcp    pop3   FIN     20     20     948    3120
# 119081  0.000003   udp     dns   INT      2      0     114       0
# 130249  0.000002   udp     dns   INT      2      0     114       0
# 170699  0.388219   tcp    http   FIN     10      6     928     268
# 47847   0.827334   tcp       -   FIN     10      8     534     354
#
#                  rate  sttl  ...  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 129193  125000.000300   254  ...                16              23
# ...

# %%
# !pip install ctgan
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 29.6 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from ctgan import CTGAN

ctgan = CTGAN(epochs=10)

ctgan.fit(dataset,list(dataset.columns))
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[32], line 4
#       1 from ctgan import CTGAN
#       2 ctgan = CTGAN(epochs=10)
# ----> 4 ctgan.fit(dataset,list(dataset.columns))
#
# File /opt/conda/lib/python3.10/site-packages/ctgan/synthesizers/base.py:50, in random_state.<locals>.wrapper(self, *args, **kwargs)
#      48 def wrapper(self, *args, **kwargs):
#      49     if self.random_states is None:
# ---> 50         return function(self, *args, **kwargs)
#      52     else:
#      53         with set_random_states(self.random_states, self.set_random_state):
#
# File /opt/conda/lib/python3.10/site-packages/ctgan/synthesizers/ctgan.py:331, in CTGAN.fit(self, train_data, discrete_columns, epochs)
#     323 self._data_sampler = DataSampler(
#     324     train_data, self._transformer.output_info_list, self._log_frequency
#     325 )
# ...
